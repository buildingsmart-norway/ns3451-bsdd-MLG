# %% [markdown]
# # Notebook to fetch NS3451 data from BSDD
#
# Resources:
# * [Documentation of bSDD API](http://bsdd.buildingsmart.org/docs/)
# * [json viewer](http://jsonviewer.stack.hu/)
# * [ns3451 BAG in bSDD](http://bsdd.buildingsmart.org/#concept/details/1BautCwov8XhSUR2I1ZKzI)
# (by searching bSDD with "ns3451" at bsdd.buildingsmart.org, the ns3451 BAG concept is found)
#
# ![NS3451 bSDD topnode](ns3451-bSDD.png)
#
# ## Goal:
# Fetch bSDD data and to creat/enrich an NS3451 ontology based on semantic web standards. Write out to .ttl file.
#
# ## Objectives:
# * pars bSDD and create an internal structure with higher level API to concept properties of interest.
# * Create NS3451 ontology
# * Link to relevant other ontologies like BOT, etc.
#
# ## Evaluate models:
# * Skos
# * OWL with subclassing
# * OWL with HasMembers and HasParts relations.
#
# Create SKOS model similar to [BuildingType table | Bygningstypetabellen](https://register.geonorge.no/byggesoknad/bygningstype) which can be downloaded to [rdf from here](https://register.geonorge.no/byggesoknad/bygningstype.rdf)

# %%
### bSDD API atuhentication 
import requests
base_url = "http://bsdd.buildingsmart.org/api/4.0"
ses = requests.Session()

SN_Context_Guid = '2tLzm05EyHt00000PR1IRl'
# http://bsdd.buildingsmart.org/#concept/details/1HwkeC0XXAFv0xdVFtrkpg
automation56guid="3pJwQaYyD5UQQ2uPOb1S8i"
headers = { "Accept" : "application/json" ,"Content-Type" : "application/x-www-form-urlencoded" }

def bsdd_login(user_email,user_password, session):
    ## /session/login
    mount= "/session/login"
    data ={"email":user_email,"password":user_password}
    return session.post(base_url+mount ,headers = headers ,data = data )

## Uncomment this if Children are in a restricted context. session object should handle cookie object in later calls.
## User needs to have access to context with the relevent relationships in bSDD. 
## NS3451 is in a open Standards Norway context, so its not neede for this case. 
"""user = str(input("Email: "))
password = str(input("Password: "))
r = bsdd_login(user,password,ses)
print(r.status_code)"""
def bsdd_concept_children(concept_guid,session):
    ## /IfdConcept/{guid}/children 
    mount = "/IfdConcept/{}/children".format(concept_guid)
    return session.get(base_url+mount,headers = headers)

r2 = bsdd_concept_children("3vHUaooT0Hsm00051Mm008",ses)
print(r2.status_code)

def bsdd_concept_search(search_string,session,concept_type="BAG"):
    ## /api/4.0/IfdConcept/search/filter/type/{conceptType}/{searchString}
    mount = "/IfdConcept/search/filter/type/{}/{}".format(concept_type,search_string)
    return session.get(base_url+mount,headers = headers)
r3 = bsdd_concept_search("NS3451",ses)
print(r3.status_code)
#print(r3.json())

def bsdd_concept_pick(concept_guid,session):
    ## /api/4.0/IfdConcept/{guid}
    mount = "/IfdConcept/{}".format(concept_guid)
    return session.get(base_url+mount,headers = headers)
r4 = bsdd_concept_pick(automation56guid,ses)
print(r4.status_code)
#print(r4.json())
# Out:
# 200
# 200
# 200

# %%
## Created a class for representing IfdObjects from bSDD

class IfdConcept():
    def __init__(self,ifd_concept):
        
        self.guid = ifd_concept["guid"] if "guid"in ifd_concept else ""
        self.definitions = ifd_concept["definitions"] if "definitions" in ifd_concept  else ""
        self.fullNames = ifd_concept["fullNames"] if "fullNames"in ifd_concept else ""
        self.shortNames = ifd_concept["shortNames"] if "shortNames"in ifd_concept else ""
        self.conceptType = ifd_concept["conceptType"] if "conceptType"in ifd_concept else ""
        self.contexts = ifd_concept["contexts"] if "contexts"in ifd_concept else ""
        self.base_url = "http://bsdd.buildingsmart.org/api/4.0"
        
    def getDescriptions(self):
        # returns a dictionary with tuples of format (description,language code)
        # or None if no norwegian or english description where found. 
        descriptions = {}
        if isinstance(self.definitions,dict):
                if self.definitions["language"]["languageCode"] == "nb-NO":
                    descriptions["no"] = (self.definitions["description"],self.definitions["language"]["languageCode"])
                if self.definitions["language"]["languageCode"] == "en":
                    descriptions["en"] = (self.definitions["description"],self.definitions["language"]["languageCode"])
        elif isinstance(self.definitions,list):
            for item in self.definitions:
                if item["language"]["languageCode"] == "nb-NO":
                    descriptions["no"] = (item["description"],item["language"]["languageCode"])
                if item["language"]["languageCode"] == "en":
                    descriptions["en"] = (item["description"],item["language"]["languageCode"])
        
        if descriptions is {}:
            return None
        else:
            return descriptions
                
    def getFullNames(self):
        # returns a dictionary with tuples of format (name,language code)
        # or None if no norwegian or english description where found. 
        
        names = {}
        for item in self.fullNames:
            if item["language"]["languageCode"] == "nb-NO":
                names["no"] = (item["name"],item["language"]["languageCode"])
            if item["language"]["languageCode"] == "en":
                names["en"] = (item["name"],item["language"]["languageCode"])
        if names is {}:
            return None
        else:
            return names

    def getShortNames(self):
        # returns a dictionary with tuples of format (name,language code)
        # or None if no norwegian or english description where found. 
        names = {}
        for item in self.shortNames:
            if item["language"]["languageCode"] == "nb-NO":
                names["no"] = (item["name"],item["language"]["languageCode"])
            if item["language"]["languageCode"] == "en":
                names["en"] = (item["name"],item["language"]["languageCode"])
        if names is {}:
            return None
        else:
            return names

    def getConceptType(self):
        # returns concept type in a string
        return self.conceptType
    
    def getConceptUrl(self):
        # Returns the full bSDD API mount uri for the concept. 
        return "http://bsdd.buildingsmart.org/#concept/details/"+self.guid
    def getConceptUri(self):
        # Returns the full bSDD API mount uri for the concept. 
        return "http://bsdd.buildingsmart.org/api/4.0/IfdConcept/"+self.guid
    
    def getGuid(self):
        # returns the bSDD guid for the concept in a string
        return self.guid
    
    def getChildren(self,session):
        ## /IfdConcept/{guid}/children/COMPOSES
        ## only gets "HasParts"/"COMPOSES" relatated objects
        mount = "/IfdConcept/{}/children/COMPOSES".format(self.guid)
        children = []
        res = session.get(self.base_url+mount,headers = headers).json()
        #print(res)
        if res and isinstance(res["IfdConceptInRelationship"],dict):
            children.append(IfdConcept(res["IfdConceptInRelationship"]))
            return children
        elif res and isinstance(res["IfdConceptInRelationship"],list):
            #print("Entered if list, lengt of list is: "+str(len(res["IfdConceptInRelationship"])))
            for child in res["IfdConceptInRelationship"]:
                children.append(IfdConcept(child))
            return children
        else: 
            return None 
    
## testing 
print("Test Number 1: \n--------------------------------------------------------------------------")
testObject = IfdConcept(r4.json())
print(testObject.getDescriptions())
print(testObject.getFullNames())
print(testObject.getShortNames())
print(testObject.getConceptType())
print(testObject.getConceptUrl())
print(testObject.getChildren(ses))
print("Test Number 2: \n--------------------------------------------------------------------------")
testObject2 = IfdConcept(r3.json()["IfdConcept"])
print(testObject2.getDescriptions())
print(testObject2.getFullNames())
print(testObject2.getShortNames())
print(testObject2.getConceptType())
print(testObject2.getConceptUrl())
print(testObject2.getChildren(ses))
# Out:
# Test Number 1:
# --------------------------------------------------------------------------
# {'no': ('Omfatter tele- og automatiseringsinstallasjoner for drift og virksomhet.', 'nb-NO')}
# {'no': ('Tele og automatisering, generelt', 'nb-NO'), 'en': ('Tele and automation, general', 'en')}
# {'no': ('50', 'nb-NO'), 'en': ('50', 'en')}
# CLASSIFICATION
# http://bsdd.buildingsmart.org/#concept/details/3pJwQaYyD5UQQ2uPOb1S8i
# None
# Test Number 2:
# --------------------------------------------------------------------------
# {'en': ('-', 'en'), 'no': ('-', 'nb-NO')}
# {'en': ('NS3451', 'en'), 'no': ('NS3451', 'nb-NO')}
# {}
# BAG
# http://bsdd.buildingsmart.org/#concept/details/1BautCwov8XhSUR2I1ZKzI
# None

# %% [markdown]
# ## Create ontology based on context
#
# ref. LDAC19 TBOX lecture
#
# Multiple languages: Literal(“a”, lang=”fr”) ref. https://buildmedia.readthedocs.org/media/pdf/rdflib/latest/rdflib.pdf
#
# first name ontology, and use this url as example: https://ont.buildingsmart.no/

# %%
from rdflib import Graph , Literal , BNode , Namespace , RDF , RDFS , OWL , URIRef, XSD
import os

# %% [markdown]
# ## Create a Ontology for NS3451 as in Standard Norway context in bSDD
#
# ### Alt 1:
# Create four level ontology with **subclassing**. Four classes, from one digit level to four digit level building element.
#
# ### Alt 2:
# Create four level ontolgoy with **HasParts** relations. Four classes, from one digit level to four digit level building element.
#
# ### Alt 3:
# Create three level skos taxonomy. Skos:ConceptSchema with three/four level classes, that has "narrower" relations between.
# Create skos:concepts of the respective conceptschema type
#
# ### Alt 4:
# Create a one level skos codelist. Skos: ConceptSchema with ontly one class - buildingElement.
# Create skos:concepts of all three level/four level elements.
#
#
# ### Alt 4 seams to match best practise best for these kind of taxanomies.
#
# 1. ref.: https://docs.ontowiki.net/How-to-create-and-publish-a-SKOS-taxonomy-in-5-minutes.html
# 2. ref.: https://link.springer.com/article/10.1057/dam.2010.29
# 3. ref.: https://joinup.ec.europa.eu/collection/semantic-interoperability-community-semic/document/tutorial-give-software-taxonomies-multilingual-labels-represented-skos
#
# As NS3451 is a taxonomy with only three structure of broad/narrow Modelling and linking guide poposes the following stack:
#
# Ref. CEN 442 WG4 TG3
# Should use Level 1 for Taxonomies:
#
# XML Schema Part2: Datatypes
#
# * xsd:float, xsd:double, xsd:decimal
# * xsd:integer, xsd:string, xsd:boolean
# * xsd:date, xsd:time, xsd:dateTime, xsd:duration
# * xsd:anyURI
# * xsd:anyType
#
# RDF
#
# * rdf:Property
# * rdf:type
# * rdf:HTML (for rich textual content)
#
# SKOS
#
# * skos:Concept
# * skos:definition
# * skos:notation
# * skos:example
# * skos:scopeNote
# * skos:prefLabel
# * skos:altLabel
# * skos:editorialNote
# * skos:broader
# * skos:narrower
# * skos:closeMatch
# * skos:exactMatch
#
# --> Additionally I'll use SKOS:ConceptInScheme, RDFS:seeAlso
# --> Should maybe also use dcterms for description etc.?
# --> Why not use more of RDFS:comments etc insstead of skos:definitions

# %%
### Create SKOS.Scheme for BuildingElement/Bygningselement
## All elements of NS3451 are building elements on different specificity levels and categories. 

g = Graph()

g.bind( "owl" , OWL )
NS = Namespace( "https://ont.buildingsmart.no/ns3451#" )
g.bind( "ont" , NS )

SKOS = Namespace( "http://www.w3.org/2004/02/skos/core#" )
g.bind( "skos" , SKOS )

schema_no = "Bygningsdel"
schema_en = "BuildingElement"

s = NS[schema_no]
p = RDF.type
o = SKOS.ConceptScheme
g.add( ( s , p , o ) )

p = SKOS.prefLabel
o = Literal(schema_no,lang="nb-no")
g.add( ( s , p , o ) )

p = SKOS.altLabel
o = Literal(schema_no,lang="nb-no")
g.add( ( s , p , o ) )

g.serialize( destination = "ns3451-skos.ttl" , format = "ttl" )
print( "Created ns3451-skos.ttl in folder:" )
print( str( os.getcwd() ) )
# Out:
# Created ns3451-skos.ttl in folder:
# /Users/Sigve/Projects/bSN/SummerSchoolOfLDAC/Notebooks

# %%
def addIndividual(ifdObjects,narrower_concept_name=""):
    for ifdObj in ifdObjects:
        
        # Getting Attributes from bSDD Object
        name = ifdObj.getFullNames()["no"][0].replace(" ","-")
        print(name)
        prefLabel = ifdObj.getFullNames()["no"][0]
        altLabel = ifdObj.getFullNames()["en"][0]
        if "no" in ifdObj.getShortNames():
            description = ifdObj.getShortNames()["no"][0]
        elif "en" in ifdObj.getShortNames():
            description = ifdObj.getShortNames()["en"][0]
        else:
            print(name)
            description = "NA"
        seeAlso = ifdObj.getConceptUri()
        htmlLabel = ifdObj.getConceptUrl()

        s = NS[name]
        p = RDF.type
        o = SKOS.Concept
        g.add( ( s , p , o ) )

        p = SKOS.prefLabel
        o = Literal(prefLabel,lang="no")
        g.add( ( s , p , o ) )

        p = SKOS.altLabel
        o = Literal(altLabel,lang="en")
        g.add( ( s , p , o ) )

        p = SKOS.definition
        o = Literal(description,lang="no")
        g.add( ( s , p , o ) )

        p = SKOS.inScheme
        o = NS[schema_no]
        g.add( ( s , p , o ) )

        p = SKOS.topConceptOf
        o = NS[schema_no]
        g.add( ( s , p , o ) )

        p = RDFS.seeAlso
        o = Literal(htmlLabel,lang="no")
        g.add( ( s , p , o ) )

        if not narrower_concept_name == "":
            p = SKOS.broader
            o = NS[narrower_concept_name]
            g.add( ( s , p , o ) )
        children = ifdObj.getChildren(ses)
        if children:
            print("parent name is: {} and number of children are {}".format(name,len(children)))    
            addIndividual(children,name)

# %% [markdown]
# ## "Top Node" of NS3451 in bSDD
#
# NS3451:2009 is the top level collection of the classification of the version 2009. The link to this is: [bSDD link](https://www.dropbox.com/s/fmlane569jj5kdu/Screenshot%202019-06-18%2010.04.46.png?dl=0)
#
# This is added as the first SKOS Concept below.

# %%
#top node "3qhov7DEn0ORoAeFXLyfC3"
topNode = bsdd_concept_pick("3qhov7DEn0ORoAeFXLyfC3",ses)
topObj = IfdConcept(topNode.json())
print(topObj.getFullNames())
print(topObj.getShortNames())
print(topObj.getDescriptions())
print(topObj.getConceptType())
print(topObj.getGuid())
print(topObj.getConceptUrl())
for child in topObj.getChildren(ses):
    print(child.getFullNames())
# Out:
# {'no': ('NS3451:2009', 'nb-NO'), 'en': ('NS3451:2009', 'en')}
# {'no': ('-', 'nb-NO'), 'en': ('-', 'en')}
# {}
# CLASSIFICATION
# 3qhov7DEn0ORoAeFXLyfC3
# http://bsdd.buildingsmart.org/#concept/details/3qhov7DEn0ORoAeFXLyfC3
# {'no': ('utendørs', 'nb-NO'), 'en': ('Outdoor', 'en')}
# {'no': ('bygning', 'nb-NO'), 'en': ('Building', 'en')}
# {'no': ('Tele og automatisering', 'nb-NO'), 'en': ('Tele and automation', 'en')}
# {'no': ('elkraft', 'nb-NO'), 'en': ('Electric power', 'en')}
# {'no': ('andre installasjoner', 'nb-NO'), 'en': ('Other installations', 'en')}
# {'no': ('VVS-installasjoner', 'nb-NO'), 'en': ('hvac', 'en')}

# %%
addIndividual([topObj])
# Out:
# NS3451:2009
# parent name is: NS3451:2009 and number of children are 6
# utendørs
# parent name is: utendørs and number of children are 10
# parker-og-hager
# parent name is: parker-og-hager and number of children are 4
# Gressarealer
# Andre-deler-for-parker-og-hager
# utstyr
# beplantning
# Utendørs-elkraft
# parent name is: Utendørs-elkraft and number of children are 6
# Utendørs-reservekraft
# Andre-installasjoner-for-utendørs-elkraft
# Utendørs-elvarme
# Utendørs-lavspent-forsyning
# parent name is: Utendørs-lavspent-forsyning and number of children are 2
# Kurser-til-utendørs-lavspent-forbruksutstyr.
# Fordelinger-for-utendørs-lavspent-forsyning
# Utendørs-høyspent-forsyning
# parent name is: Utendørs-høyspent-forsyning and number of children are 2
# Fordelingssystem-for-utendørs-høyspent-forsyning
# Nettstasjoner.
# Utendørs-lys
# veger-og-plasser
# parent name is: veger-og-plasser and number of children are 5
# plasser
# Sikkerhetsrekkverk,-avvisere-mv.
# Skilter
# Andre-deler-for-veger-og-plasser
# Veger
# Utendørs-røranlegg
# parent name is: Utendørs-røranlegg and number of children are 9
# Utendørs-fontener-og-springvann
# parent name is: Utendørs-fontener-og-springvann and number of children are 4
# Utstyr-for-utendørs-fontener-og-springvann
# Armaturer-for-utendørs-fontener-og-springvann
# Isolasjon-for-utendørs-fontener-og-springvann.
# Ledninger-i-grunnen-for-utendørs-fontener-og-springvann
# Utendørs-forsyningsanlegg-for-termisk-energi
# parent name is: Utendørs-forsyningsanlegg-for-termisk-energi and number of children are 4
# Ledninger-i-grunnen-for-termisk-energiforsyning
# Armaturer-for-termisk-energiforsyning
# Isolasjon-for-termisk-energiforsyning
# Utstyr-for-termisk-energiforsyning
# Utendørs-brannslokking
# parent name is: Utendørs-brannslokking and number of children are 4
# Ledningsnett-over-terreng-for-brannslokking
# Utstyr-for-brannslokking
# Armaturer-for-brannslokking
# Isolasjon-for-brannslokking.
# Utendørs-varme
# parent name is: Utendørs-varme and number of children are 4
# Isolasjon-for-utendørs-varme.
# Ledninger-i-grunnen-for-utendørs-varme
# Armaturer-for-utendørs-varme
# Utstyr-for-utendørs-varme
# Utendørs-kjøling-for-idrettsbaner
# parent name is: Utendørs-kjøling-for-idrettsbaner and number of children are 5
# Ledningsnett-over-terreng-for-kjøling-for-idrettsbaner
# Isolasjon-for-kjøling-for-idrettsbaner.
# Utstyr-for-kjøling-for-idrettsbaner
# Armaturer-for-kjøling-for-idrettsbaner
# Ledninger-i-grunnen-for-kjøling-for-idrettsbaner
# Utendørs-gassinstallasjoner
# parent name is: Utendørs-gassinstallasjoner and number of children are 5
# Ledningsnett-over-terreng-for-utendørs-gassinstallasjoner
# Utstyr-for-utendørs-gassinstallasjoner
# Ledninger-i-grunnen-for-utendørs-gassinstallasjoner
# Isolasjon-for-utendørs-gassinstallasjoner.
# Armaturer-for-utendørs-gassinstallasjoner
# Utendørs-luftbehandlingsanlegg
# parent name is: Utendørs-luftbehandlingsanlegg and number of children are 5
# Isolasjon-for-utendørs-luftbehandlingsanlegg.
# Utstyr-for-luftbehandling-for-utendørs-luftbehandlingsanlegg
# Kanalnett-over-terreng-for-utendørs-luftbehandlingsanlegg
# Kanaler-i-grunnen-for-utendørs-luftbehandlingsanlegg
# Utstyr-for-luftfordeling-for-utendørs-luftbehandlingsanlegg
# Andre-utendørs-røranlegg
# Utendørs-VA
# parent name is: Utendørs-VA and number of children are 4
# Utstyr-for-VA
# Armaturer-for-VA
# Isolasjon-for-VA.
# Ledninger-i-grunnen-for-VA
# Andre-utendørs-anlegg
# Utendørs,-generelt
# utendørs-konstruksjoner
# parent name is: utendørs-konstruksjoner and number of children are 8
# andre-utendørs-konstruksjoner
# gjerder,-porter-og-bommer
# Svømmebassenger-mv.
# Frittstående-skjermtak,-leskur-mv.
# støttemurer-og-andre-murer
# Kanaler-og-kulverter-for-tekniske-installasjoner
# trapper-og-ramper-i-terreng
# Kummer-og-tanker-for-tekniske-installasjoner
# bearbeidet-terreng
# parent name is: bearbeidet-terreng and number of children are 5
# Grøfter-og-groper-for-tekniske-installasjoner
# Grovplanert-terreng
# Forsterket-grunn
# Drenering
# annen-terrengbearbeiding
# Utendørs-tele-og-automatisering
# parent name is: Utendørs-tele-og-automatisering and number of children are 6
# Utendørs-alarm-og-signal
# parent name is: Utendørs-alarm-og-signal and number of children are 2
# Utendørs-brannalarm
# Utendørs-adgangskontroll,-innbrudds--og-overfallsalarm.
# Utendørs-integrert-kommunikasjon
# parent name is: Utendørs-integrert-kommunikasjon and number of children are 2
# Kabling-for-utendørs-IKT
# Terminalutstyr-for-utendørs-IKT.
# Utendørs-automatisering
# parent name is: Utendørs-automatisering and number of children are 3
# Utendørs-buss-system.
# Utendørs-lokalautomatisering
# Utendørs-sentral-driftskontroll
# Andre-installasjoner-for-utendørs-tele-og-automatisering
# Utendørs-lyd-og-bilde
# parent name is: Utendørs-lyd-og-bilde and number of children are 3
# Utendørs-lyddistribusjon.
# Utendørs-fellesantenner
# Utendørs-internfjernsyn
# Utendørs-telefoni-og-personsøkning
# parent name is: Utendørs-telefoni-og-personsøkning and number of children are 3
# Utendørs-porttelefoner
# Utendørs-telefoni
# Utendørs-høyttalende-hustelefoner.
# Utendørs-infrastruktur
# parent name is: Utendørs-infrastruktur and number of children are 4
# Andre-deler-for-utendørs-infrastruktur
# Tilknytning-til-eksternt-telenett
# Tilknytning-til-eksternt-elkraftnett
# Tilknytning-til-eksterne-nett-for-vannforsyning,-avløp-og-fjernvarme
# bygning
# parent name is: bygning and number of children are 10
# Grunn-og-fundamenter.
# parent name is: Grunn-og-fundamenter. and number of children are 9
# Drenering
# utstyr-og-komplettering
# direkte-fundamentering
# Andre-deler-av-grunn-og-fundamenter
# Grunnforsterkning
# Klargjøring-av-tomt-
# pelefundamentering
# støttekonstruksjoner
# Byggegrop-
# Trapper,-balkonger-m.m.
# parent name is: Trapper,-balkonger-m.m. and number of children are 9
# baldakiner-og-skjermtak
# ramper
# Andre-trapper,-balkonger-m.m.
# balkonger-og-verandaer
# innvendige-trapper
# Utstyr-og-kompletteringer
# tribuner-og-amfier
# andre-rekkverk,-håndlister-og-fendere
# utvendige-trapper
# dekker
# parent name is: dekker and number of children are 9
# gulvoverflate
# faste-himlinger-og-overflatebehandling
# gulvsystemer
# gulv-på-grunn
# systemhimlinger
# utstyr-og-komplettering
# Andre-deler-av-dekker
# Oppfôret-gulv,-påstøp
# frittbærende-dekker
# innervegger
# parent name is: innervegger and number of children are 8
# utstyr-og-komplettering
# bærende-innervegger
# skjørt
# Andre-deler-av-innervegg
# systemvegger,-glassfelt
# kledning-og-overflate
# ikke-bærende-innervegger
# vinduer,-dører,-foldevegger
# Bygning,-generelt
# yttervegger
# parent name is: yttervegger and number of children are 9
# innvendig-overflate
# bærende-yttervegger
# vinduer,-dører,-porter
# glassfasader
# Andre-deler-av-yttervegg
# utstyr-og-komplettering
# Ikke-bærende-yttervegger
# solavskjerming
# utvendig-kledning-og-overflate
# yttertak
# parent name is: yttertak and number of children are 9
# Utstyr-og-kompletteringer
# primærkonstruksjon
# Andre-deler-av-yttertak
# gesimser,-takrenner-og-nedløp
# prefabrikkerte-takelementer
# Taktekning
# glasstak,-overlys,-takluker
# takoppbygg
# himling-og-innvendig-overflate
# andre-bygningsmessige-deler
# fast-inventar
# parent name is: fast-inventar and number of children are 9
# skap-og-reoler
# sittebenker,-stolrader,-bord
# monteringsferdige-ildsteder
# Utstyr-og-kompletteringer
# skilt-og-tavler
# kjøkkeninnredning
# Annet-fast-inventar
# innredning-og-garnityr-for-våtrom
# murte-piper-og-ildsteder
# bæresystemer
# parent name is: bæresystemer and number of children are 8
# Rammer
# brannbeskyttelse-av-bærende-konstruksjoner
# Andre-deler-av-bæresystem
# utstyr-og-komplettering
# avstivende-konstruksjoner
# kledning-og-overflate
# søyler
# bjelker
# Tele-og-automatisering
# parent name is: Tele-og-automatisering and number of children are 9
# instrumentering
# parent name is: instrumentering and number of children are 9
# Instrumentering-for-måling-av-elektriske-størrelser
# Instrumentering-for-måling-av-mengde
# Instrumentering-for-måling-av-lengde
# Instrumentering-for-måling-av-trykk
# Kabling-for-instrumentering
# parent name is: Kabling-for-instrumentering and number of children are 7
# Kurser-for-måling-av-mengde
# Kurser-for-måling-av-trykk
# Kurser-for-måling-av-temperatur
# Kurser-for-måling-av-vekt
# Kurser-for-måling-av-lengde
# Kurser-for-måling-av-elektriske-størrelser
# Kurser-for-analyseinstrumenter.
# Instrumentering-for-måling-av-vekt
# Instrumentering-for-analyse
# Instrumentering-for-måling-av-temperatur
# Annen-instrumentering
# basisinstallasjoner-for-tele-og-automatisering
# parent name is: basisinstallasjoner-for-tele-og-automatisering and number of children are 5
# jording
# systemer-for-kabelføring
# Andre-basisinstallasjoner-for-tele-og-automatisering
# Telefordelinger
# Inntakskabler-for-teleanlegg
# Tele-og-automatisering,-generelt
# alarm--og-signalsystemer
# parent name is: alarm--og-signalsystemer and number of children are 5
# pasientsignal
# parent name is: pasientsignal and number of children are 3
# Utstyr-for-anrop,-tilstedemarkering,-anropsvisning,-alarm-mv.-for-pasientsignal.
# Sentralutstyr-for-pasientsignal
# Kurser-for-pasientsignal
# Uranlegg-og-tidsregistrering
# parent name is: Uranlegg-og-tidsregistrering and number of children are 3
# Sentralutstyr-for-uranlegg-og-tidsregistrering
# Biur,-terminaler-mv.-for-uranlegg-og-tidsregistrering.
# Kurser-for-uranlegg-og-tidsregistrering
# brannalarm
# parent name is: brannalarm and number of children are 3
# Kurser-for-brannalarm
# Sentralutstyr-for-brannalarm
# Detektorer,-meldere,-alarmorgan-mv.-for-brannalarm.
# Andre-deler-for-alarm-og-signal
# adgangskontroll,-innbrudds--og-overfallsalarm
# parent name is: adgangskontroll,-innbrudds--og-overfallsalarm and number of children are 3
# Detektorer,-forbikoblere,-alarmorgan-mv.-for-adgangskontroll,-innbrudds--og-overfallsalarm.
# Kurser-for-adgangskontroll,-innbrudds--og-overfallsalarm
# Sentralutstyr-for-adgangskontroll,-innbruddsog-overfallsalarm
# integrert-kommunikasjon
# parent name is: integrert-kommunikasjon and number of children are 5
# Terminalutstyr
# kabling-for-ikt
# nettutstyr
# sentralutstyr
# Andre-deler-for-integrert-kommunikasjon
# Andre-installasjoner-for-tele-og-automatisering
# Telefoni-og-personsøkning
# parent name is: Telefoni-og-personsøkning and number of children are 5
# systemer-for-telefoni
# parent name is: systemer-for-telefoni and number of children are 3
# Terminalutstyr-for-telefoni.
# Kurser-for-telefoni
# Sentralutstyr-for-telefoni
# Systemer-for-porttelefoner
# parent name is: Systemer-for-porttelefoner and number of children are 3
# Sentralutstyr-for-porttelefoner
# Kurser-for-porttelefoner
# Terminalutstyr-for-porttelefoner.
# Andre-deler-for-telefoni-og-personsøkning
# Systemer-for-høyttalende-hustelefoner
# parent name is: Systemer-for-høyttalende-hustelefoner and number of children are 3
# Kurser-for-høyttalende-hustelefoner
# Terminalutstyr-for-høyttalende-hustelefoner.
# Sentralutstyr-for-høyttalende-hustelefoner
# Systemer-for-personsøkning
# parent name is: Systemer-for-personsøkning and number of children are 3
# Sentralutstyr-for-personsøking
# Kurser-for-personsøking
# Terminalutstyr-for-personsøking.
# Lyd--og-bildesystemer
# parent name is: Lyd--og-bildesystemer and number of children are 6
# bilde-og-av-systemer
# parent name is: bilde-og-av-systemer and number of children are 3
# Terminalutstyr-for-informasjons--og-AVsystemer.
# Sentralutstyr-og-styretablåer-for-informasjons-og-AV-systemer
# Kurser-med-uttak-for-informasjons--og-AVsystemer
# lydanlegg
# parent name is: lydanlegg and number of children are 4
# Mikrofoner-og-høyttalere-for-lydanlegg
# Kurser-med-uttak-for-lydanlegg
# Forsterkerutstyr,-lydkilder,-styreutstyr-mv.-for-lydanlegg
# Utstyr-for-overføring-til-høreapparater.
# Fellesantenner
# parent name is: Fellesantenner and number of children are 3
# Tilkoblingskabler-for-apparater.
# Kurser-med-uttak-for-fellesantenner
# Sentralutstyr/forsterker-for-fellesantenner
# Lyddistribusjonsanlegg
# parent name is: Lyddistribusjonsanlegg and number of children are 3
# Kurser-med-uttak-for-lyddistribusjon
# Forsterkerutstyr,-lydkilder,-miksebord-mv.-for-lyddistribusjon
# Mikrofoner-og-høyttalere-for-lyddistribusjon.
# Andre-deler-for-lyd--og-bildesystemer
# internfjernsyn
# parent name is: internfjernsyn and number of children are 3
# Sentralutstyr/forsterkere-for-internfjernsyn
# Kurser-for-internfjernsyn
# Kameraer,-monitorer-velgerutstyr-mv.-for-internfjernsyn.
# automatisering
# parent name is: automatisering and number of children are 5
# FDVUS:-Administrative-systemer
# Sentral-driftskontroll-og-automatisering
# parent name is: Sentral-driftskontroll-og-automatisering and number of children are 3
# Kurser-for-sentral-driftskontroll
# Sentralutstyr-for-sentral-driftskontroll
# Følere,-givere,-forstillingsorgan-mv.-for-sentral-driftskontroll.
# Andre-deler-for-automatisering
# buss-systemer
# parent name is: buss-systemer and number of children are 2
# Kurser-for-buss-systemer
# Utstyr-for-buss-systemer.
# Lokal-automatisering
# parent name is: Lokal-automatisering and number of children are 3
# Kurser-for-lokal-automatisering
# Sentralutstyr-for-lokal-automatisering
# Følere,-givere,-forstillingsorgan-mv.-for-lokal-automatisering.
# elkraft
# parent name is: elkraft and number of children are 8
# Andre-elkraftinstallasjoner
# elkraft,-generelt
# reservekraft
# parent name is: reservekraft and number of children are 4
# Andre-deler-for-reservekraftforsyning
# akkumulatoranlegg
# avbruddsfri-kraftforsyning
# Elkraftaggregater
# elvarme
# parent name is: elvarme and number of children are 4
# Vannvarmere-og-elektrokjeler
# Annen-elvarme
# Varmeelementer-for-innebygging
# parent name is: Varmeelementer-for-innebygging and number of children are 2
# Flatevarmeelementer
# Varmekabler.
# varmeovner
# lys
# parent name is: lys and number of children are 3
# Andre-deler-for-installasjoner-til-lys
# Nødlysutstyr
# parent name is: Nødlysutstyr and number of children are 4
# Armaturer-for-markeringslys
# Armaturer-for-reservelys
# Armaturer-for-orienteringslys
# Armaturer-for-antipanikkbelysning.
# Belysningsutstyr
# parent name is: Belysningsutstyr and number of children are 3
# Elektrisk-belysningsutstyr
# Utstyr-for-optisk-overføring-og-styring-av-lys
# Utstyr-for-innfanging,-overføring-og-spredning-av-dagslys.-
# høyspent-forsyning
# parent name is: høyspent-forsyning and number of children are 3
# Fordelingssystemer
# Andre-deler-for-høyspent-forsyning
# Nettstasjoner-
# lavspent-forsyning
# parent name is: lavspent-forsyning and number of children are 6
# System-for-elkraftinntak
# elkraftfordeling-til-alminnelig-forbruk
# parent name is: elkraftfordeling-til-alminnelig-forbruk and number of children are 2
# Fordelinger-til-alminnelig-forbruk
# Kursopplegg-til-alminnelig-forbruk.
# elkraftfordeling-til-driftstekniske-installasjoner
# parent name is: elkraftfordeling-til-driftstekniske-installasjoner and number of children are 2
# Fordelinger-for-driftstekniske-installasjoner
# Kursopplegg-for-driftstekniske-installasjoner.
# Systemer-for-hovedfordeling
# parent name is: Systemer-for-hovedfordeling and number of children are 2
# Hovedfordeling
# Stigekabler.
# Andre-deler-for-lavspent-forsyning
# elkraftfordeling-til-virksomhet
# parent name is: elkraftfordeling-til-virksomhet and number of children are 2
# Fordelinger-for-virksomhet
# Kursopplegg-for-virksomhet.
# basisinstallasjoner-for-elkraft
# parent name is: basisinstallasjoner-for-elkraft and number of children are 5
# systemer-for-lynvern
# systemer-for-elkraftuttak
# parent name is: systemer-for-elkraftuttak and number of children are 3
# Uttakspaneler.
# grenstaver
# Installasjonskanaler-med-integrerte-installasjoner-og-utstyr
# systemer-for-kabelføring
# parent name is: systemer-for-kabelføring and number of children are 2
# Kabelstiger,-kabelkanaler,-kabelbrett
# Installasjonskanaler-med-uttaksbokser.
# Andre-basisinstallasjoner-for-elkraft
# systemer-for-jording
# andre-installasjoner
# parent name is: andre-installasjoner and number of children are 9
# Avfall-og-støvsuging
# parent name is: Avfall-og-støvsuging and number of children are 4
# Sentralstøvsuger
# parent name is: Sentralstøvsuger and number of children are 5
# Armaturer
# Ledninger-i-grunnen
# Isolasjon.
# Ledningsnett
# utstyr
# Utstyr-for-oppsamling-og-behandling-av-avfall
# Pneumatisk-søppeltransport
# parent name is: Pneumatisk-søppeltransport and number of children are 4
# Kanalnett
# Kanaler-i-grunnen
# Utstyr.
# Armaturer-(innkastluker)
# Andre-installasjoner-for-avfall-og-støvsuging
# Transportanlegg-for-småvarer-mv.
# parent name is: Transportanlegg-for-småvarer-mv. and number of children are 3
# Andre-transportanlegg-for-småvarer-mv.
# Dokument--og-småvaretransportører
# Transportanlegg-for-tørr-og-løs-masse
# parent name is: Transportanlegg-for-tørr-og-løs-masse and number of children are 6
# Isolasjon-av-installasjoner-for-pneumatisk-transport
# Armaturer-for-pneumatisk-transport
# Ledningsnett-for-pneumatisk-transport
# Brukerutstyr-for-pneumatisk-transport.
# Utstyr-for-pneumatisk-transport
# Ledninger-i-grunnen-for-pneumatisk-transport
# Fastmontert-spesialutrustning-for-virksomhet
# Løs-spesialutrustning-for-virksomhet
# person--og-varetransport
# parent name is: person--og-varetransport and number of children are 8
# kraner
# trappeheiser
# Heiser-Personheiser,-sengeheiser-og-kombinerte-person--og-vareheiser.
# Annen-person--og-varetransport
# rulletrapper
# løftebord
# Rullebånd-For-persontransport.
# fasade--og-takvask
# Andre-installasjoner,-generelt
# Sceneteknisk-utstyr
# Prefabrikkerte-rom
# parent name is: Prefabrikkerte-rom and number of children are 6
# Prefabrikkerte-baderom
# Prefabrikkerte-sjakter
# Prefabrikkerte-kjølerom
# Andre-prefabrikkerte-rom
# Prefabrikkerte-skjermrom
# Prefabrikkerte-fryserom
# Andre-tekniske-installasjoner
# VVS-installasjoner
# parent name is: VVS-installasjoner and number of children are 10
# brannslokking
# parent name is: brannslokking and number of children are 6
# Andre-deler-av-installasjoner-for-brannslokking
# installasjon-for-brannslokking-med-sprinkler
# parent name is: installasjon-for-brannslokking-med-sprinkler and number of children are 5
# Ledninger-i-grunnen-for-brannslokking-med-sprinkler
# Isolasjon-for-brannslokking-med-sprinkler.
# Ledningsnett-for-brannslokking-med-sprinkler
# Utstyr-for-brannslokking-med-sprinkler
# Armaturer-for-brannslokking-med-sprinkler
# installasjon-for-brannslokking-med-inertgass
# parent name is: installasjon-for-brannslokking-med-inertgass and number of children are 5
# Isolasjon-for-brannslokking-med-inertgass.
# Ledninger-i-grunnen-for-brannslokking-med-inertgass
# Ledningsnett-for-brannslokking-med-inertgass
# Armaturer-for-brannslokking-med-inertgass
# Utstyr-for-brannslokking-med-inertgass
# installasjon-for-manuell-brannslokking-med-vann
# parent name is: installasjon-for-manuell-brannslokking-med-vann and number of children are 5
# Ledninger-i-grunnen-for-manuell-brannslokking
# Isolasjon-for-manuell-brannslokking.
# Ledningsnett-for-manuell-brannslokking
# Utstyr-for-manuell-brannslokking
# Armaturer-for-manuell-brannslokking
# installasjon-for-brannslokking-med-pulver
# parent name is: installasjon-for-brannslokking-med-pulver and number of children are 5
# Armaturer-for-brannslokking-med-pulver
# Ledningsnett-for-brannslokking-med-pulver
# Isolasjon-for-brannslokking-med-pulver.
# Ledninger-i-grunnen-for-brannslokking-med-pulver
# Utstyr-for-brannslokking-med-pulver
# installasjon-for-brannslokking-med-vanntåke
# parent name is: installasjon-for-brannslokking-med-vanntåke and number of children are 5
# Ledninger-i-grunnen-for-brannslokking-med-vanntåke
# Armaturer-for-brannslokking-med-vanntåke
# Ledningsnett-for-brannslokking-med-vanntåke
# Isolasjon-for-brannslokking-med-vanntåke.
# Utstyr-for-brannslokking-med-vanntåke
# komfortkjøling
# parent name is: komfortkjøling and number of children are 6
# utstyr-for-komfortkjøling
# ledningsnett-for-komfortkjøling
# Isolasjon-av-installasjon-for-komfortkjøling
# ledningsnett-i-grunnen-for-komfortkjøling
# Armaturer-for-komfortkjøling
# Andre-deler-for-komfortkjøling
# luftbehandling
# parent name is: luftbehandling and number of children are 6
# isolasjon-av-installasjon-for-luftbehandling
# parent name is: isolasjon-av-installasjon-for-luftbehandling and number of children are 5
# Isolasjon-av-installasjon-for-krigsventilasjon.
# Isolasjon-av-installasjon-for-balansert-ventilasjon
# Isolasjon-av-installasjon-for-avtrekksventilasjon
# Isolasjon-av-installasjon-for-naturlig-oppdriftsventilasjon
# Isolasjon-av-installasjon-for-røyk--og-brannventilasjon
# Utstyr-for-luftfordeling-Gitre,-lufthetter,-ventiler,-dyser-mv.
# parent name is: Utstyr-for-luftfordeling-Gitre,-lufthetter,-ventiler,-dyser-mv. and number of children are 5
# Utstyr-for-luftfordeling-for-krigsventilasjon.
# Utstyr-for-luftfordeling-for-avtrekksventilasjon
# Utstyr-for-luftfordeling-for-naturlig-oppdriftsventilasjon
# Utstyr-for-luftfordeling-for-balansert-ventilasjon
# Utstyr-for-luftfordeling-for-røyk--og-brannventilasjon
# kanalnett-i-grunnen-for-luftbehandling
# parent name is: kanalnett-i-grunnen-for-luftbehandling and number of children are 5
# Kanalnett-i-grunnen-for-balansert-ventilasjon
# Kanalnett-i-grunnen-for-naturlig-oppdriftsventilasjon
# Kanalnett-i-grunnen-for-røyk--og-brannventilasjon
# Kanalnett-i-grunnen-for-krigsventilasjon.
# Kanalnett-i-grunnen-for-avtrekksventilasjon
# kanalnett-for-luftbehandling
# parent name is: kanalnett-for-luftbehandling and number of children are 5
# Kanalnett-for-røyk--og-brannventilasjon
# Kanalnett-for-naturlig-oppdriftsventilasjon
# Kanalnett-for-balansert-ventilasjon
# Kanalnett-for-avtrekksventilasjon
# Kanalnett-for-krigsventilasjon.
# Annet-utstyr-for-luftbehandling
# utstyr-for-luftbehandling
# parent name is: utstyr-for-luftbehandling and number of children are 5
# Utstyr-for-luftbehandling-for-balansert-ventilasjon
# Utstyr-for-luftbehandling-for-røyk--og-brannventilasjon
# Utstyr-for-luftbehandling-for-naturlig-oppdriftsventilasjon
# Utstyr-for-luftbehandling-for-avtrekksventilasjon
# Utstyr-for-luftbehandling-for-krigsventilasjon.
# gass-og-trykkluft
# parent name is: gass-og-trykkluft and number of children are 7
# installasjon-til-medisinsk-trykkluft
# parent name is: installasjon-til-medisinsk-trykkluft and number of children are 5
# Armaturer-for-medisinsk-trykkluft
# Ledninger-i-grunnen-for-medisinsk-trykkluft
# Utstyr-for-medisinsk-trykkluft
# Isolasjon-for-medisinsk-trykkluft.
# Ledningsnett-for-medisinsk-trykkluft
# Installasjon-til-medisinske-gasser
# parent name is: Installasjon-til-medisinske-gasser and number of children are 5
# Ledningsnett-for-medisinske-gasser
# Ledninger-i-grunnen-for-medisinske-gasser
# Utstyr-for-medisinske-gasser
# Armaturer-for-medisinske-gasser
# Isolasjon-for-medisinske-gasser.
# installasjon-til-gass-for-bygningsdrift
# parent name is: installasjon-til-gass-for-bygningsdrift and number of children are 5
# Isolasjon-for-gass-til-bygningsdrift.
# Armaturer-for-gass-til-bygningsdrift
# Ledninger-i-grunnen-for-gass-til-bygningsdrift
# Ledningsnett-for-gass-til-bygningsdrift
# Utstyr-for-gass-til-bygningsdrift
# vakuumsystemer
# parent name is: vakuumsystemer and number of children are 5
# Isolasjon-for-vakuumsystemer.
# Utstyr-for-vakuumsystemer
# Ledninger-i-grunnen-for-vakuumsystemer
# Ledningsnett-for-vakuumsystemer
# Armaturer-for-vakuumsystemer
# installasjon-til-trykkluft-for-virksomhet-i-ferdig-bygg
# parent name is: installasjon-til-trykkluft-for-virksomhet-i-ferdig-bygg and number of children are 5
# Ledningsnett-for-trykkluft-til-virksomhet
# Utstyr-for-trykkluft-til-virksomhet
# Isolasjon-for-trykkluft-til-virksomhet.
# Ledninger-i-grunnen-for-trykkluft-til-virksomhet
# Armaturer-for-trykkluft-til-virksomhet
# Andre-deler-av-installasjoner-til-gass-og-trykkluft
# installasjon-til-gass-for-virksomhet-i-ferdig-bygg
# parent name is: installasjon-til-gass-for-virksomhet-i-ferdig-bygg and number of children are 5
# Isolasjon-for-gass-til-virksomhet.
# Utstyr-for-gass-til-virksomhet
# Ledninger-i-grunnen-for-gass-til-virksomhet
# Ledningsnett-for-gass-til-virksomhet
# Armaturer-for-gass-til-virksomhet
# Generelt-vedr.-VVSinstallasjoner
# vannbehandling
# parent name is: vannbehandling and number of children are 5
# Systemer-for-rensing-av-forbruksvann
# parent name is: Systemer-for-rensing-av-forbruksvann and number of children are 5
# Utstyr-for-rensing-av-forbruksvann
# Armaturer-for-rensing-av-forbruksvann
# Ledningsnett-for-rensing-av-forbruksvann
# Isolasjon-for-rensing-av-forbruksvann.
# Ledninger-i-grunnen-for-rensing-av-forbruksvann
# Andre-deler-for-vannbehandling
# Systemer-for-rensing-av-vann-til-svømmebasseng
# parent name is: Systemer-for-rensing-av-vann-til-svømmebasseng and number of children are 5
# Armaturer-for-vannrensing-til-svømmebasseng
# Isolasjon-for-vannrensing-til-svømmebasseng.
# Ledninger-i-grunnen-for-vannrensing-til-svømmebasseng
# Utstyr-for-vannrensing-til-svømmebasseng
# Ledningsnett-for-vannrensing-til-svømmebasseng
# Systemer-for-rensing-av-avløpsvann
# parent name is: Systemer-for-rensing-av-avløpsvann and number of children are 5
# Isolasjon-for-rensing-av-avløpsvann.
# Armaturer-for-rensing-av-avløpsvann
# Utstyr-for-rensing-av-avløpsvann
# Ledningsnett-for-rensing-av-avløpsvann
# Ledninger-i-grunnen-for-rensing-av-avløpsvann
# Innendørs-fontener-og-springvann
# parent name is: Innendørs-fontener-og-springvann and number of children are 5
# Armaturer-for-innendørs-fontener-og-springvann
# Ledninger-i-grunnen-for-innendørs-fontener-og-springvann
# Isolasjon-for-innendørs-fontener-og-springvann.
# Ledningsnett-for-innendørs-fontener-og-springvann
# Utstyr-for-innendørs-fontener-og-springvann
# Sanitær
# parent name is: Sanitær and number of children are 6
# isolasjon-av-sanitærinstallasjoner
# parent name is: isolasjon-av-sanitærinstallasjoner and number of children are 3
# Isolasjon-av-installasjon-for-spillvann
# Isolasjon-av-installasjon-for-forbruksvann.
# Isolasjon-av-installasjon-for-overvann
# Andre-deler-av-sanitærinstallasjoner
# utstyr-for-sanitærinstallasjoner
# parent name is: utstyr-for-sanitærinstallasjoner and number of children are 3
# Utstyr-for-forbruksvann.
# Utstyr-for-spillvann
# Utstyr-for-overvann
# Ledningsnett-for-sanitærinstallasjoner
# parent name is: Ledningsnett-for-sanitærinstallasjoner and number of children are 3
# Ledningsnett-for-spillvann
# Ledningsnett-for-overvann
# Ledningsnett-for-forbruksvann.
# armaturer-for-sanitærinstallasjoner
# parent name is: armaturer-for-sanitærinstallasjoner and number of children are 3
# Armaturer-for-spillvann
# Armaturer-for-forbruksvann.
# Armaturer-for-overvann
# bunnledninger-for-sanitærinstallasjoner
# parent name is: bunnledninger-for-sanitærinstallasjoner and number of children are 3
# Bunnledninger-for-overvann
# Bunnledninger-for-forbruksvann.
# Bunnledninger-for-spillvann
# prosesskjøling
# parent name is: prosesskjøling and number of children are 6
# kjøleromsystemer
# parent name is: kjøleromsystemer and number of children are 5
# Ledningsnett-for-kjøleromsystemer
# Utstyr-for-kjøleromsystemer
# Isolasjon-for-kjøleromsystemer.
# Ledninger-i-grunnen-for-kjøleromsystemer
# Armaturer-for-kjøleromsystemer
# Andre-deler-av-installasjoner-for-kulde--og-kjølesystemer
# fryseromsystemer
# parent name is: fryseromsystemer and number of children are 5
# Ledningsnett-for-fryseromsystemer
# Armaturer-for-fryseromsystemer
# Utstyr-for-fryseromsystemer
# Isolasjon-for-fryseromsystemer.
# Ledninger-i-grunnen-for-fryseromsystemer
# Kjølesystemer-for-produksjon
# parent name is: Kjølesystemer-for-produksjon and number of children are 5
# Utstyr-for-kjølesystemer-for-produksjon
# Ledninger-i-grunnen-for-kjølesystemer-for-produksjon
# Isolasjon-for-kjølesystemer-for-produksjon.
# Armaturer-for-kjølesystemer-for-produksjon
# Ledningsnett-for-kjølesystemer-for-produksjon
# Kuldesystemer-for-innendørs-idrettsbaner
# kjølesystemer-for-virksomhet
# parent name is: kjølesystemer-for-virksomhet and number of children are 5
# Ledninger-i-grunnen-for-kjølesystemer-for-virksomhet
# Isolasjon-for-kjølesystemer-for-virksomhet.
# Utstyr-for-kjølesystemer-for-virksomhet
# Ledningsnett-for-kjølesystemer-for-virksomhet
# Armaturer-for-kjølesystemer-for-virksomhet
# varme
# parent name is: varme and number of children are 6
# bunnledninger-for-varmeinstallasjoner
# parent name is: bunnledninger-for-varmeinstallasjoner and number of children are 4
# Bunnledninger-for-varmesystem-med-lavtemperert-damp
# Bunnledninger-for-varmesystem-med-høytemperert-damp.
# Bunnledninger-for-varmesystem-med-lavtemperert-vann
# Bunnledninger-for-varmesystem-med-høytemperert-vann
# utstyr-for-varmeinstallasjoner
# parent name is: utstyr-for-varmeinstallasjoner and number of children are 4
# Utstyr-for-varmesystem-med-lavtemperert-vann
# Utstyr-for-varmesystem-med-lavtemperert-damp
# Utstyr-for-varmesystem-med-høytemperert-damp.
# Utstyr-for-varmesystem-med-høytemperert-vann
# Andre-deler-av-varmeinstallasjoner
# Armaturer-for-varmeinstallasjon
# parent name is: Armaturer-for-varmeinstallasjon and number of children are 4
# Armaturer-for-varmesystem-med-høytemperert-vann
# Armaturer-for-varmesystem-med-lavtemperert-vann
# Armaturer-for-varmesystem-med-lavtemperert-damp
# Armaturer-for-varmesystem-med-høytemperert-damp.
# isolasjon-av-varmeinstallasjoner
# parent name is: isolasjon-av-varmeinstallasjoner and number of children are 4
# Isolasjon-av-varmesystem-med-lavtemperert-vann
# Isolasjon-av-varmesystem-med-høytemperert-vann
# Isolasjon-av-varmesystem-med-lavtemperert-damp
# Isolasjon-av-varmesystem-med-høytemperert-damp.
# ledningsnett-for-varmeinstallasjoner
# parent name is: ledningsnett-for-varmeinstallasjoner and number of children are 4
# Ledningsnett-for-varmesystem-med-lavtemperert-vann
# Ledningsnett-for-varmesystem-med-høytemperert-vann
# Ledningsnett-for-varmesystem-med-lavtemperert-damp
# Ledningsnett-for-varmesystem-med-høytemperert-damp.
# Andre-VVSinstallasjoner

# %%
g.serialize( destination = "ns3451-skos.ttl" , format = "ttl" )
print( "Created ns3451-skos.ttl in folder:" )
print( str( os.getcwd() ) )
# Out:
# Created ns3451-skos.ttl in folder:
# /Users/Sigve/Projects/bSN/SummerSchoolOfLDAC/Notebooks
